# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# %run '/gdrive/MyDrive/Thesis/Deployment/Constants.ipynb'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# %run '/gdrive/MyDrive/Thesis/Deployment/UtilityFunctions.ipynb'

# %%
'''Task: Read the data from csv file - EEG_data.csv'''

'''eegData=pd.read_csv(file1)
dgInfo=pd.read_csv(file2)'''
# Out:
# 'eegData=pd.read_csv(file1)\ndgInfo=pd.read_csv(file2)'

# %%
''' Task: Data pre-processing'''
#eegData=dgInfo=pd.DataFrame()
#eegData, dgInfo, videoLength = preProcessData(eegData, dgInfo)
# Out:
# ' Task: Data pre-processing'

# %%
'''eegFeatureSet=genFeatures(eegData)
eegFeatureSet=addFeatures(eegFeatureSet, eegData, dgInfo)
eegFeatureSet['VideoLen']=videoLength'''
# Out:
# "eegFeatureSet=genFeatures(eegData)\neegFeatureSet=addFeatures(eegFeatureSet, eegData, dgInfo)\neegFeatureSet['VideoLen']=videoLength"

# %%
#eegScaled=dataScaling(eegFeatureSet, eegData)
testData = pickle.load(open('/gdrive/MyDrive/Thesis/Deployment/model.pkl', 'rb'))
Xtest, ytest=testData[0], testData[1]

# %%
'''Predict on test data'''
model=testData[3]

# %%
yhat=model.predict(Xtest)
plotConfusionMatrix(yhat, ytest)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        10
#            1       0.75      0.90      0.82        10
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.80      0.80        20
# weighted avg       0.81      0.80      0.80        20

# %%
yhat
['Confused' if result==1 else 'Not Confused' for result in yhat]
# Out:
# ['Confused',
#  'Confused',
#  'Not Confused',
#  'Not Confused',
#  'Confused',
#  'Not Confused',
#  'Confused',
#  'Confused',
#  'Confused',
#  'Not Confused',
#  'Confused',
#  'Confused',
#  'Not Confused',
#  'Confused',
#  'Not Confused',
#  'Confused',
#  'Not Confused',
#  'Confused',
#  'Confused',
#  'Not Confused']

# %%
yhat
# Out:
# array([1, 1, 0, 0, 1, 0, 1, 1, 1, 0, 1, 1, 0, 1, 0, 1, 0, 1, 1, 0])
