# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# %run '/gdrive/MyDrive/Thesis/Deployment/Constants.ipynb'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# %run '/gdrive/MyDrive/Thesis/Deployment/UtilityFunctions.ipynb'

# %%
'''Task: Read the data from csv file - EEG_data.csv'''
eegData=pd.read_csv(file1)
dgInfo=pd.read_csv(file2)

eegData=eegData.rename(columns=lambda r: r.strip())
dgInfo=dgInfo.rename(columns=lambda r: r.strip())

# %%
''' Task: Data pre-processing.'''
eegData, dgInfo, videoLength = preProcessData(eegData, dgInfo)

# %%
'''Task : Generates the Feature set'''
eegFeatureSet=genFeatures(eegData)
eegFeatureSet=addFeatures(eegFeatureSet, dgInfo, videoLength)

# %%
'''Split the train test sets. Scale the data. 
This is only training module. Just return train data'''
Xtrain, ytrain, scaler= eegScaled=dataScaling(eegFeatureSet, eegData, kbestcols)

# %%
#indTrain, indTest = splitTrainTest(eegScaled)

# %%
'''Create the model'''
model=LogisticRegression(C=lrc)
model.fit(Xtrain, ytrain.UsrTgtLabel.to_list())
# Out:
# LogisticRegression(C=0.1)

# %%
'''Save the required data'''
pickle.dump([kbestcols, scaler, model], open('/gdrive/MyDrive/Thesis/Deployment/model.pkl', 'wb'))
